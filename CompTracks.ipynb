# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/TrkAna","/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
import numpy as np
np.set_printoptions(precision=6)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/TrkAna
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages', '/home/online1/brownd/mu2e/pyana/TrkAna', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import CompTracks
import SurfaceIds

# %%
#file=["/data/HD6/users/brownd/ntp.test6_regrow.root"]
#file=["/data/HD6/users/brownd/ntp.regrow.test12.root"]
file=["/data/HD6/users/brownd/ntp.brownd.regrow.test13.root"]
file=["/data/HD6/users/brownd/ntp.ensembleMDS1eMix1BBTriggerable.regrow14.root"]

# %%
ct1= CompTracks.CompTracks(1,11)

# %%
ct1.Loop(file,"EventNtuple/ntuple")
# Out:
# Processing batch

# %%
ct1.PlotMom()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ct1.PlotMom()
#
# File ~/mu2e/pyana/TrkAna/CompTracks.py:179, in CompTracks.PlotMom(self)
#     176 delmom = self.HDeltaMom.plot(deltaMom)
#     178 # fit momentum difference (core)
# --> 179 maxval = self.HDeltaMom.maxVal()
#     180 #print("maxval",maxval)
#     181 binrange = self.HDeltaMom.binRange(0.1*maxval)
#
# AttributeError: 'MyHist' object has no attribute 'maxVal'

# %%
ct1.PlotCount()

# %%
ct1.PlotQuality()

# %%
ct0= CompTracks.CompTracks(0,11)

# %%
ct0.Loop(file,"EventNtuple/ntuple")

# %%
ct0.PlotMom()
