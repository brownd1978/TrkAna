# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/TrkAna","/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
import numpy as np
np.set_printoptions(precision=6)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/TrkAna
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages', '/cvmfs/mu2e.opensciencegrid.org/spackages/241207/spack/opt/spack/linux-almalinux9-x86_64_v2/gcc-11.5.0/muse-4.17.0-di7thnqtj43r5ojxh6gum5pqg42mwmn2/python', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python312.zip', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/lib-dynload', '/home/online1/brownd/mu2e/pyana/TrkAna', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import CompTracks
import SurfaceIds

# %%
#file=["/data/HD6/users/brownd/ntp.test6_regrow.root"]
#file=["/data/HD6/users/brownd/ntp.regrow.test12.root"]
#file=["/data/HD6/users/brownd/ntp.brownd.regrow.test13.root"]
#file=["/data/HD6/users/brownd/ntp.ensembleMDS1eMix1BBTriggerable.Regrow14.root"]
#file=["/data/HD6/users/brownd/ntp.mcs.CeEndpointMix1BBTriggerable.regrow14.root"]
file=["/data/HD6/users/brownd//ntp.mu2e.CeEndpointMix1BBTriggerable.regrowce_brehms.root"]
file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggerable.MDC2025ad_best_v1_3_regrow_7.root"]
file =["/data/HD5/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2025ae_best_v1_3_regrow.root"]
file =["/data/HD5/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2025ae_best_v1_3_regrow2.root"]
file =["/data/HD5/users/brownd/ntp.brownd.CeEndpointOnSpillTriggered.MDC2025ae_best_v1_3_regrow.root"]

# %%
ct1= CompTracks.CompTracks(1,11)

# %%
ct1.Loop(file,"EventNtuple/ntuple")
# Out:
# Processing batch  0

# %%
ct1.PlotInters()
# Out:
# Primary # of intersections 1197 Target Inters 336 IPA Inters 148
# Secondary # of intersections 1368 Target Inters 337 IPA Inters 265

# %%
#ct1.PlotMom()

# %%
#ct1.PlotCount()

# %%
#ct1.PlotQuality()

# %%
#ct0= CompTracks.CompTracks(0,11)

# %%
#ct0.Loop(file,"EventNtuple/ntuple")

# %%
#ct0.PlotMom()
