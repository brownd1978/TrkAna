# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/TrkAna","/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/TrkAna
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages', '/home/online1/brownd/mu2e/pyana/TrkAna', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import DeRes
import SurfaceIds
import ShowTree as ST

# %%
file=["/data/HD5/users/brownd/ntp.De.debug.root"]

# %%
#ST.Branches(file[0])

# %%
de = DeRes.DeRes([100,110],[-1,1],15,0.0,0.0)

# %%
import numpy as np
np.set_printoptions(precision=6)
de.Loop(file)
# Out:
# Processing batch  0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
#       2 np.set_printoptions(precision=6)
# ----> 3 de.Loop(file)
#
# File ~/mu2e/pyana/TrkAna/DeRes.py:280, in DeRes.Loop(self, files)
#     272             segsMC = batch['trksegsmc'] # SurfaceStep infor for true primary particle
#     273 #            tsmplane = batch['trkmats.plane']
#     274 #            tsmpanel = batch['trkmats.panel']
#     275 #            tsmstraw = batch['trkmats.straw']
#    (...)
#     278 #            tshstraw = batch['trkhits.straw']
#     279             # should be 1 track/event
# --> 280             assert(ak.sum(ak.count_nonzero(nhits,axis=1)!=1) == 0)
#     281             segs = segs[:,0]
#     282             lhpars = lhpars[:,0]
#
# AssertionError:

# %%
de.PlotStraws()

# %%
de.PlotPathlength()

# %%
#de.PlotMaterial()

# %%
#de.PlotTarget()

# %%
de.PlotTrackerMomentum()

# %%
de.PlotQuality()
