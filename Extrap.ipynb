# %% [markdown]
# #

# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/TrkAna","/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/TrkAna
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages', '/cvmfs/mu2e.opensciencegrid.org/spackages/241207/spack/opt/spack/linux-almalinux9-x86_64_v2/gcc-11.5.0/muse-4.17.0-di7thnqtj43r5ojxh6gum5pqg42mwmn2/python', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python312.zip', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12', '/cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/lib-dynload', '/home/online1/brownd/mu2e/pyana/TrkAna', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import DeRes
import SurfaceIds
import ShowTree as ST

# %%
file = ["/data/HD5/users/brownd/ntp.brownd.RefRegrowe.root"]
file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2025ae_best_v1_3.root"]

# %%
#ST.Branches(file[0],"ENe/ntuple")

# %%
de = DeRes.DeRes([100,106],[-1,1],15,0.0,0.0,0)

# %%
import numpy as np
np.set_printoptions(precision=6)
de.Loop(file)
# Out:
# Processing batch  0
# ---------------------------------------------------------------------------
# FieldNotFoundError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 import numpy as np
#       2 np.set_printoptions(precision=6)
# ----> 3 de.Loop(file)
#
# File ~/mu2e/pyana/TrkAna/DeRes.py:283, in DeRes.Loop(self, files)
#     281 event = batch['event']
#     282 segs = batch['trksegs'] # track fit samples
# --> 283 mats = batch['trkmats'] # track passive materials (straws)
#     284 lhpars = batch['trksegpars_lh'] # track fit samples
#     285 nhits = batch['trk.nhits']  # track N hits
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/highlevel.py:1106, in Array.__getitem__(self, where)
#     677 def __getitem__(self, where):
#     678     """
#     679     Args:
#     680         where (many types supported; see below): Index of positions to
#    (...)   1104     have the same dimension as the array being indexed.
#    1105     """
# -> 1106     with ak._errors.SlicingErrorContext(self, where):
#    1107         # Handle named axis
#    1108         (_, ndim) = self._layout.minmax_depth
#    1109         named_axis = _get_named_axis(self)
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/_errors.py:80, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      78     self._slate.__dict__.clear()
#      79     # Handle caught exception
# ---> 80     raise self.decorate_exception(exception_type, exception_value)
#      81 else:
#      82     # Step out of the way so that another ErrorContext can become primary.
#      83     if self.primary() is self:
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/highlevel.py:1114, in Array.__getitem__(self, where)
#    1110 where = _normalize_named_slice(named_axis, where, ndim)
#    1112 NamedAxis.mapping = named_axis
# -> 1114 indexed_layout = prepare_layout(self._layout._getitem(where, NamedAxis))
#    1116 if NamedAxis.mapping:
#    1117     return ak.operations.ak_with_named_axis._impl(
#    1118         indexed_layout,
#    1119         named_axis=NamedAxis.mapping,
#    (...)   1122         attrs=self._attrs,
#    1123     )
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/contents/content.py:553, in Content._getitem(self, where, named_axis)
#     550     return self._getitem((where,), named_axis)
#     552 elif isinstance(where, str):
# --> 553     return self._getitem_field(where)
#     555 elif where is np.newaxis:
#     556     return self._getitem((where,), named_axis)
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/contents/recordarray.py:513, in RecordArray._getitem_field(self, where, only_fields)
#     509 def _getitem_field(
#     510     self, where: str | SupportsIndex, only_fields: tuple[str, ...] = ()
#     511 ) -> Content:
#     512     if len(only_fields) == 0:
# --> 513         return self.content(where)
#     515     else:
#     516         nexthead, nexttail = ak._slicing.head_tail(only_fields)
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/contents/recordarray.py:439, in RecordArray.content(self, index_or_field)
#     438 def content(self, index_or_field: str | SupportsIndex) -> Content:
# --> 439     out = super().content(index_or_field)
#     440     if (
#     441         self.length is unknown_length
#     442         or out.length is unknown_length
#     443         or out.length == self.length
#     444     ):
#     445         return out
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/_meta/recordmeta.py:140, in RecordMeta.content(self, index_or_field)
#     138     index = index_or_field
#     139 elif isinstance(index_or_field, str):
# --> 140     index = self.field_to_index(index_or_field)
#     141 else:
#     142     raise TypeError(
#     143         f"index_or_field must be an integer (index) or string (field), not {index_or_field!r}"
#     144     )
#
# File /cvmfs/mu2e.opensciencegrid.org/env/ana/2.7.0/lib/python3.12/site-packages/awkward/_meta/recordmeta.py:121, in RecordMeta.field_to_index(self, field)
#     119     else:
#     120         return i
# --> 121 raise FieldNotFoundError(
#     122     f"no field {field!r} in record with {len(self._contents)} fields"
#     123 )
#
# FieldNotFoundError: no field 'trkmats' in record with 67 fields
#
# This error occurred while attempting to slice
#
#     <Array [{event: 2, run: 1430, ...}, ...] type='985 * {event: int32, run...'>
#
# with
#
#     'trkmats'

# %%
de.PlotStraws()

# %%
#de.PlotPathlength()

# %%
#de.PlotRadLoss()

# %%
de.PlotTarget()

# %%
de.PlotTrackerMomentum()

# %%
de.PlotQuality()

# %%
de.PlotELoss()
